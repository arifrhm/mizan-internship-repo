# %% [markdown]
# Import Library yang Diperlukan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings
# Out:
# <function warnings.filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)>

# %% [markdown]
# ####Read Data Awal

# %%
df = pd.read_excel("donasi_online_update_12_maret_2022.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24453 entries, 0 to 24452
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tanggal       24453 non-null  datetime64[ns]
#  1   id_transaksi  24453 non-null  float64
#  2   id_donatur    24453 non-null  float64
#  3   nominal       24453 non-null  float64
#  4   akad          24453 non-null  object
#  5   program       24186 non-null  object
#  6   payment       24417 non-null  object
#  7   platform      23852 non-null  object
#  8   type_trans    24443 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 1.7+ MB

# %%
df.head(10)
# Out:
#               tanggal  id_transaksi  id_donatur    nominal               akad  \
# 0 2022-03-12 07:48:12       47409.0     31812.0   100000.0              Wakaf
# 1 2022-03-12 07:37:43       47408.0     31812.0   100000.0      Infaq Sedekah
# 2 2022-03-12 06:29:53       47400.0     25104.0    20000.0      Infaq Sedekah
# 3 2022-03-12 05:03:13       47399.0     28057.0    50000.0       Panti Asuhan
# 4 2022-03-11 20:09:57        4413.0     18008.0    50000.0  Zakat Penghasilan
# 5 2022-03-11 19:45:36       47397.0     27628.0    50000.0      Infaq Sedekah
# 6 2022-03-11 16:55:36       47396.0     32196.0  2500000.0      Infaq Sedekah
# 7 2022-03-11 14:16:00       47394.0     25795.0    50000.0      Infaq Sedekah
# 8 2022-03-11 14:15:14       47393.0     32288.0    50000.0      Infaq Sedekah
# 9 2022-03-11 13:04:35       47392.0     36101.0   150000.0      Infaq Sedekah
#
#                                              program                  payment  \
# ...

# %%
df.tail(10)
# Out:
#                   tanggal  id_transaksi  id_donatur    nominal  \
# 24443 2019-12-29 09:42:19          37.0     27217.0    50000.0
# 24444 2019-12-27 17:00:00          17.0     27257.0   150000.0
# 24445 2019-12-26 17:00:00          16.0     27261.0   150000.0
# 24446 2019-12-23 17:00:00          29.0     27253.0   131000.0
# 24447 2019-12-23 17:00:00          31.0     26232.0  1450000.0
# 24448 2019-12-23 17:00:00          32.0     27250.0   250000.0
# 24449 2019-12-17 17:00:00         129.0     25812.0      100.0
# 24450 2019-12-17 17:00:00         130.0     25812.0      100.0
# 24451 2019-12-17 17:00:00         137.0     25812.0      100.0
# 24452 2019-12-17 17:00:00          45.0     23403.0   650000.0
#
#                     akad                                      program  \
# 24443        Kemanusiaan         donasi_selamatkan_generasi_palestina
# 24444  Zakat Penghasilan                            Zakat Penghasilan
# ...

# %%
df.describe(include="all")
# Out:
# /var/folders/q6/3sqvgn8d0fxbmcwfdkl_n4ph0000gn/T/ipykernel_1924/1985922364.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include="all")
#                     tanggal  id_transaksi    id_donatur       nominal  \
# count                 24453  24453.000000  24453.000000  2.445300e+04
# unique                24343           NaN           NaN           NaN
# top     2020-11-14 16:56:13           NaN           NaN           NaN
# freq                     11           NaN           NaN           NaN
# first   2019-12-17 17:00:00           NaN           NaN           NaN
# last    2022-03-12 07:48:12           NaN           NaN           NaN
# mean                    NaN  24755.019711  27087.001677  1.916196e+05
# ...

# %% [markdown]
# ####Export Excel Data Tanggal dan Nominal

# %%
df2 = df.resample('D', on='tanggal').nominal.sum()
df2
# Out:
# tanggal
# 2019-12-17     650300.0
# 2019-12-18          0.0
# 2019-12-19          0.0
# 2019-12-20          0.0
# 2019-12-21          0.0
#                 ...
# 2022-03-08    2460400.0
# 2022-03-09     520000.0
# 2022-03-10    1331062.0
# 2022-03-11    7382305.0
# 2022-03-12     270000.0
# Freq: D, Name: nominal, Length: 817, dtype: float64

# %%
df2.to_excel("data_aggregate_sum_tanggal_nominal.xlsx")

# %%
#after processing in excel
df3 = pd.read_excel("data_aggregate_sum_tanggal_nominal_2.xlsx")
df3
# Out:
#        tanggal  nominal
# 0   2019-12-01        0
# 1   2019-12-02        0
# 2   2019-12-03        0
# 3   2019-12-04        0
# 4   2019-12-05        0
# ..         ...      ...
# 847 2022-03-27        0
# 848 2022-03-28        0
# 849 2022-03-29        0
# 850 2022-03-30        0
# 851 2022-03-31        0
#
# [852 rows x 2 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tanggal  852 non-null    datetime64[ns]
#  1   nominal  852 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 13.4 KB

# %% [markdown]
# ID Donatur masing - masing secara RFM
# <br />
# Dashboard V1 (Google Data Studio)
# <br/>
# Tanggal dan Payment
# <br/>
# Aggregasi per hari (Format data kalender)
# <br/>
# Program-program TOP 5
# <br/>
# Donatur Loyalis dan Kurang Loyal

# %%
df.isnull().sum()
# Out:
# tanggal           0
# id_transaksi      0
# id_donatur        0
# nominal           0
# akad              0
# program         267
# payment          36
# platform        601
# type_trans       10
# dtype: int64

# %%
category_columns=df.select_dtypes(include=['object']).columns.tolist()

for column in category_columns:
    if df[column].isnull().any():
          df[column]=df[column].fillna(df[column].mode()[0])

print(df.head(10))
print(df.tail(10))
# Out:
#               tanggal  id_transaksi  id_donatur    nominal               akad  \
# 0 2022-03-12 07:48:12       47409.0     31812.0   100000.0              Wakaf
# 1 2022-03-12 07:37:43       47408.0     31812.0   100000.0      Infaq Sedekah
# 2 2022-03-12 06:29:53       47400.0     25104.0    20000.0      Infaq Sedekah
# 3 2022-03-12 05:03:13       47399.0     28057.0    50000.0       Panti Asuhan
# 4 2022-03-11 20:09:57        4413.0     18008.0    50000.0  Zakat Penghasilan
# 5 2022-03-11 19:45:36       47397.0     27628.0    50000.0      Infaq Sedekah
# 6 2022-03-11 16:55:36       47396.0     32196.0  2500000.0      Infaq Sedekah
# 7 2022-03-11 14:16:00       47394.0     25795.0    50000.0      Infaq Sedekah
# 8 2022-03-11 14:15:14       47393.0     32288.0    50000.0      Infaq Sedekah
# 9 2022-03-11 13:04:35       47392.0     36101.0   150000.0      Infaq Sedekah
#
#                                              program                  payment  \
# ...

# %%
df.isnull().sum()
# Out:
# tanggal         0
# id_transaksi    0
# id_donatur      0
# nominal         0
# akad            0
# program         0
# payment         0
# platform        0
# type_trans      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24453 entries, 0 to 24452
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tanggal       24453 non-null  datetime64[ns]
#  1   id_transaksi  24453 non-null  float64
#  2   id_donatur    24453 non-null  float64
#  3   nominal       24453 non-null  float64
#  4   akad          24453 non-null  object
#  5   program       24453 non-null  object
#  6   payment       24453 non-null  object
#  7   platform      24453 non-null  object
#  8   type_trans    24453 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 1.7+ MB

# %%
df.to_excel("donasi_online_12_maret_no_null.xlsx")

# %%
df.describe()
# Out:
#        id_transaksi    id_donatur       nominal
# count  24453.000000  24453.000000  2.445300e+04
# mean   24755.019711  27087.001677  1.916196e+05
# std    14652.322718   6356.390739  5.545980e+05
# min        9.000000  14409.000000  1.000000e+00
# 25%    11599.000000  24462.000000  2.000000e+04
# 50%    27065.000000  27645.000000  1.000000e+05
# 75%    37965.000000  32099.000000  2.000000e+05
# max    47409.000000  36132.000000  2.000063e+07

# %%
df.describe(include='all')
# Out:
# /var/folders/q6/3sqvgn8d0fxbmcwfdkl_n4ph0000gn/T/ipykernel_1924/2884002236.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include='all')
#                     tanggal  id_transaksi    id_donatur       nominal  \
# count                 24453  24453.000000  24453.000000  2.445300e+04
# unique                24343           NaN           NaN           NaN
# top     2020-11-14 16:56:13           NaN           NaN           NaN
# freq                     11           NaN           NaN           NaN
# first   2019-12-17 17:00:00           NaN           NaN           NaN
# last    2022-03-12 07:48:12           NaN           NaN           NaN
# mean                    NaN  24755.019711  27087.001677  1.916196e+05
# ...

# %%
df_payment_count = df['payment'].value_counts()
df_payment_count.to_excel("payment_value_count.xlsx")
df_payment_count
# Out:
# bank_transfer                      9162
# gopay                              5416
# echannel                           1563
# MANDIRI                            1016
# DANA                                904
#                                    ...
# BNI Syariah - 5455440006              1
# BCA - EDC  Yayasan Mizan Amanah       1
# CREDITCARD                            1
# Akulaku                               1
# Madndiri Bill                         1
# Name: payment, Length: 71, dtype: int64

# %%
df_payment = pd.read_excel('payment_value_counts.xlsx')
df_payment
# Out:
#                          Unnamed: 0  payment
# 0                     bank_transfer     9162
# 1                             gopay     5416
# 2                          echannel     1563
# 3                           MANDIRI     1016
# 4                              DANA      904
# ..                              ...      ...
# 66         BNI Syariah - 5455440006        1
# 67  BCA - EDC  Yayasan Mizan Amanah        1
# 68                       CREDITCARD        1
# 69                          Akulaku        1
# 70                    Madndiri Bill        1
#
# [71 rows x 2 columns]

# %%
df[df['payment'].str.contains('MANDIRI')]
# Out:
#                   tanggal  id_transaksi  id_donatur   nominal  \
# 11    2022-03-11 11:26:50       47390.0     36071.0  100000.0
# 31    2022-03-11 06:37:59       47372.0     30732.0   20000.0
# 33    2022-03-11 06:24:19       47371.0     36070.0   20000.0
# 36    2022-03-11 05:27:17        4404.0     18619.0  150000.0
# 39    2022-03-10 20:37:00       47365.0     30732.0   20000.0
# ...                   ...           ...         ...       ...
# 9859  2021-04-16 05:02:24       33545.0     24263.0   50000.0
# 9861  2021-04-16 04:59:08       33543.0     24263.0   50000.0
# 9882  2021-04-15 14:11:29       33467.0     34648.0   10000.0
# 10938 2021-03-04 19:27:53       31592.0     14951.0   50000.0
# 11087 2021-02-26 22:55:19       31228.0     25735.0  212500.0
#
#                     akad                                            program  \
# 11           Kemanusiaan                                Perjuangan Bu Popon
# ...

# %%
df[df['nominal']==1].value_counts
# Out:
# <bound method DataFrame.value_counts of                   tanggal  id_transaksi  id_donatur  nominal           akad  \
# 4618  2021-10-11 10:06:29       40810.0     35652.0      1.0    Kemanusiaan
# 4883  2021-09-30 10:04:31       40387.0     25640.0      1.0   Panti Asuhan
# 4939  2021-09-28 13:06:28       40315.0     25640.0      1.0   Panti Asuhan
# 5995  2021-08-12 13:53:12       38755.0     35652.0      1.0    Kemanusiaan
# 6025  2021-08-10 10:20:35       38718.0     35652.0      1.0    Kemanusiaan
# ...                   ...           ...         ...      ...            ...
# 23248 2020-05-14 16:55:36        2863.0     26229.0      1.0  Infaq Sedekah
# 23250 2020-05-14 16:36:23        2860.0     26229.0      1.0  Infaq Sedekah
# 23252 2020-05-14 16:22:11        2858.0     26229.0      1.0  Infaq Sedekah
# 23257 2020-05-14 15:01:09        2853.0     26229.0      1.0  Infaq Sedekah
# 23258 2020-05-14 14:57:06        2851.0     26229.0      1.0  Infaq Sedekah
#
# ...

# %%
df[df['payment'].str.contains(pat="BCA",case=False)]:
# Out:
#   Input In [27]
#     df[df['payment'].str.contains(pat="BCA",case=False)]:
#                                                          ^
# SyntaxError: invalid syntax
